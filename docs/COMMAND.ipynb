# %%
! XLA_PYTHON_CLIENT_PREALLOCATE=false CUDA_VISIBLE_DEVICES=1 uv run myosuite/envs/myo/mjx/train_jax_ppo.py \
 --env_name=MjxHandReachRandom-v0 --impl=warp --num_envs=1024 --log_to_wandb

# %%
XLA_PYTHON_CLIENT_PREALLOCATE=false CUDA_VISIBLE_DEVICES=1 uv run train_jax_ppo.py --env_name=MjxHandReachRandom-v0 --impl=warp --num_envs=1024 --log_to_wandb

# %%
! XLA_PYTHON_CLIENT_PREALLOCATE=false CUDA_VISIBLE_DEVICES=1 uv run myosuite/envs/myo/mjx/train_jax_ppo.py \
    --env_name=MjxHandReachRandom-v0 \
    --impl=warp --num_envs=1024 \
    --log_to_wandb \
    --save_policy

# %%
! XLA_PYTHON_CLIENT_PREALLOCATE=false CUDA_VISIBLE_DEVICES=1 uv run train_jax_ppo.py \
    --env_name=MjxHandReachRandomCustom-v0\
    --impl=warp --num_envs=1024 \
    --log_to_wandb \
    --save_policy
